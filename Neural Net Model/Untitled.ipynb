# %%
# Initial imports
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from sklearn.neighbors import KNeighborsClassifier
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import tensorflow as tf
get_ipython().run_line_magic("matplotlib", "inline")
# %matplotlib inline

# %%
nltk.download("vader_lexicon")
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\godz7\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Load .env enviroment variables
load_dotenv()


# Set Alpaca API key and secret
alpaca_api_key = os.getenv('ALPACA_API_KEY')
alpaca_secret_key = os.getenv('ALPACA_SECRET_KEY')

api = tradeapi.REST('PKYSIX5VD8DLHIZOILZS', 'Yv4AYGCNo9puqbXGPq2zF1sNrzy63CWCrWNJnOse', api_version='v2')

# %%
def stock_info_grab(ticker):
    """
    Takes ticker symbol and returns DataFrame with Date, Close, and Pct Change columns.
    """
    # Set timeframe to '1D'
    timeframe = "1D"

    # Set current date and the date from one month ago using the ISO format
    current_date = pd.Timestamp("2020-11-09", tz="America/New_York").isoformat()
    past_date = pd.Timestamp("2016-08-27", tz="America/New_York").isoformat()

    df = api.get_barset(
        ticker,
        timeframe,
        limit=None,
        start=past_date,
        end=current_date,
        after=None,
        until=None,
    ).df
    df = df.droplevel(axis=1, level=0)
    df.index = df.index.date
    df['pct change'] = df['close'].pct_change()
    df['pct change'].dropna
    df = df.reset_index()
    df = df.drop(columns=['open', 'high', 'low', 'volume'])
    df = df.rename(columns={'index':'Date'})
    df = df.set_index('Date')
    return df

# %%
aapl_stock_info = stock_info_grab("AAPL")
amzn_stock_info = stock_info_grab("AMZN")
tsla_stock_info = stock_info_grab("TSLA")
spy_stock_info = stock_info_grab("SPY")
aapl_stock_info
# Out:
#                close  pct change
# Date
# 2016-08-29  106.8200         NaN
# 2016-08-30  105.9900   -0.007770
# 2016-08-31  106.1100    0.001132
# 2016-09-01  106.7300    0.005843
# 2016-09-02  107.7300    0.009369
# 2016-09-06  107.7000   -0.000278
# 2016-09-07  108.3700    0.006221
# 2016-09-08  105.5100   -0.026391
# 2016-09-09  103.1400   -0.022462
# 2016-09-12  105.4400    0.022300
# 2016-09-13  108.0200    0.024469
# 2016-09-14  111.7700    0.034716
# 2016-09-15  115.5700    0.033998
# 2016-09-16  114.9100   -0.005711
# 2016-09-19  113.5300   -0.012009
# 2016-09-20  113.5700    0.000352
# 2016-09-21  113.5300   -0.000352
# 2016-09-22  114.6100    0.009513
# 2016-09-23  112.7049   -0.016622
# 2016-09-26  112.8700    0.001465
# 2016-09-27  113.1100    0.002126
# 2016-09-28  113.9500    0.007426
# 2016-09-29  112.1800   -0.015533
# 2016-09-30  113.0300    0.007577
# 2016-10-03  112.5100   -0.004601
# 2016-10-04  113.0200    0.004533
# 2016-10-05  113.0400    0.000177
# 2016-10-06  113.9100    0.007696
# 2016-10-07  114.0300    0.001053
# 2016-10-10  116.0500    0.017715
# ...              ...         ...
# 2020-09-29  114.1100   -0.007739
# 2020-09-30  115.6100    0.013145
# 2020-10-01  116.8000    0.010293
# 2020-10-02  113.0200   -0.032363
# 2020-10-05  116.5400    0.031145
# 2020-10-06  113.1600   -0.029003
# 2020-10-07  115.0500    0.016702
# 2020-10-08  114.9700   -0.000695
# 2020-10-09  116.9800    0.017483
# 2020-10-12  124.4200    0.063601
# 2020-10-13  121.0500   -0.027086
# 2020-10-14  121.2900    0.001983
# 2020-10-15  120.7453   -0.004491
# 2020-10-16  118.9600   -0.014786
# 2020-10-19  116.0000   -0.024882
# 2020-10-20  117.5000    0.012931
# 2020-10-21  116.8600   -0.005447
# 2020-10-22  115.7737   -0.009296
# 2020-10-23  115.0400   -0.006337
# 2020-10-26  115.0600    0.000174
# 2020-10-27  116.5300    0.012776
# 2020-10-28  111.1500   -0.046168
# 2020-10-29  114.5200    0.030319
# 2020-10-30  108.9000   -0.049074
# 2020-11-02  108.7700   -0.001194
# 2020-11-03  110.3750    0.014756
# 2020-11-04  114.9400    0.041359
# 2020-11-05  118.9900    0.035236
# 2020-11-06  118.6850   -0.002563
# 2020-11-09  116.3200   -0.019927
#
# [1058 rows x 2 columns]

# %%
aapl_file = Path('../Resources/AAPL_HEADLINES.csv')
#amzn_file = Path('../Resources/AMZN_HEADLINES.csv')
spy_file = Path('../Resources/SPY_HEADLINES.csv')
tsla_file = Path('../Resources/TSLA_HEADLINES.csv')

aapl_headlines_df = pd.read_csv(aapl_file)
#amzn_headlines_df = pd.read_csv(amzn_file)
spy_headlines_df = pd.read_csv(spy_file)
tsla_headlines_df = pd.read_csv(tsla_file)

#aapl_headlines['Date'] = pd.to_datetime(aapl_headlines['Date']).dt.strftime('%Y-%m-%d')
#aapl_headlines = aapl_headlines.set_index('Date')
aapl_headlines_df
# Out:
#                                                Headline  \
# 0     Apple Inc. stock falls Monday, underperforms m...
# 1     Big Tech Stocks Are Lagging Today. Why They’ll...
# 2     As Apple releases its new line of Macs, the bi...
# 3     In the Midst of Election Uncertainty, Younger ...
# 4     Berkshire Buybacks Hit Record $9 Billion in Th...
# 5     This single-country stock picker has beaten th...
# 6     Apple Inc. stock falls Friday, underperforms m...
# 7     T-Mobile Stock Is at a Record High After Earni...
# 8     Dow's 25-point fall led by losses in UnitedHea...
# 9     Dow falls 110 points on losses for Apple Inc.,...
# 10    Apple's stock falls 1.2% premarket to pace the...
# 11    Apple Inc. stock outperforms market on strong ...
# 12    Alibaba Stock Is Falling. It’s Time to Pounce ...
# 13    Dow rallies 463 points on gains for shares of ...
# 14      Why the Election Means the S&P 500 Can Hit 3800
# 15    What Reviewers Are Saying About the New Apple ...
# 16    Apple Could Become a Multibillion-Dollar Ad Bu...
# 17        Apple’s Newest iPhones May Do Better in China
# 18    Never Mind Black Friday; There’s Now an Entire...
# 19    Apple Event: Is There One More Thing? (Updatin...
# 20    Zynga Beat Earnings Expectations. Why Its Stoc...
# 21    Qualcomm Stock Is Surging. It Wasn’t Just the ...
# 22    Apple could face shortage of critical chips fo...
# 23    These stocks rose the most Wednesday as invest...
# 24    The Stock Market Doesn’t Seem to Care Who Wins...
# 25    Tech Stocks Soar Amid Vote Uncertainty. Califo...
# 26    Big Tech exhales: No blue wave allays fears of...
# 27    Big Tech shares soar as fears of a blue wave s...
# 28    T-Mobile Reports Earnings Tomorrow. Here’s Wha...
# 25     Nov. 4, 2020 at 12:55 p.m. ET
# 26     Nov. 4, 2020 at 12:22 p.m. ET
# 27     Nov. 4, 2020 at 11:25 a.m. ET
# 28      Nov. 4, 2020 at 6:30 a.m. ET
# 29      Nov. 3, 2020 at 4:30 p.m. ET
# ...                              ...
# 9843   Aug. 30, 2016 at 3:29 p.m. ET
# 9844   Aug. 30, 2016 at 2:10 p.m. ET
# 9845  Aug. 30, 2016 at 11:01 a.m. ET
# 9846  Aug. 30, 2016 at 10:47 a.m. ET
# 9847  Aug. 30, 2016 at 10:41 a.m. ET
# 9848   Aug. 30, 2016 at 9:32 a.m. ET
# 9849   Aug. 30, 2016 at 9:23 a.m. ET
# 9850   Aug. 30, 2016 at 9:18 a.m. ET
# 9851   Aug. 30, 2016 at 9:06 a.m. ET
# 9852   Aug. 30, 2016 at 7:52 a.m. ET
# 9853   Aug. 30, 2016 at 7:28 a.m. ET
# 9854   Aug. 30, 2016 at 7:28 a.m. ET
# 9855   Aug. 30, 2016 at 7:27 a.m. ET
# 9856   Aug. 30, 2016 at 7:03 a.m. ET
# 9857   Aug. 30, 2016 at 6:16 a.m. ET
# 9858   Aug. 30, 2016 at 6:14 a.m. ET
# 9859   Aug. 30, 2016 at 6:11 a.m. ET
# 9860   Aug. 30, 2016 at 6:01 a.m. ET
# 9861   Aug. 30, 2016 at 3:34 a.m. ET
# 9862   Aug. 30, 2016 at 3:07 a.m. ET
# 9863   Aug. 29, 2016 at 5:00 p.m. ET
# 9864   Aug. 29, 2016 at 2:45 p.m. ET
# 9865   Aug. 29, 2016 at 2:00 p.m. ET
# 9866   Aug. 29, 2016 at 1:47 p.m. ET
# 9867  Aug. 29, 2016 at 12:21 p.m. ET
# 9868  Aug. 29, 2016 at 11:47 a.m. ET
# 9869   Aug. 29, 2016 at 9:41 a.m. ET
# 9870   Aug. 28, 2016 at 9:15 p.m. ET
# 9871  Aug. 27, 2016 at 11:02 a.m. ET
# 9872  Aug. 27, 2016 at 10:08 a.m. ET
#
# [9873 rows x 2 columns]

# %%
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
def create_sentiment_df(df):
    """
    Takes headlines DataFrame & creates DataFrame with Sentiment columns.
    Splits Date & Time, creates Time column and moves Date to Index.
    """
    title_sent = {
        "compound": [],
        "positive": [],
        "neutral": [],
        "negative": [],
        "sentiment": [],
    }

    for index, row in df.iterrows():
        try:
            # Sentiment scoring with VADER
            title_sentiment = analyzer.polarity_scores(row["Headline"])
            title_sent["compound"].append(title_sentiment["compound"])
            title_sent["positive"].append(title_sentiment["pos"])
            title_sent["neutral"].append(title_sentiment["neu"])
            title_sent["negative"].append(title_sentiment["neg"])
            title_sent["sentiment"].append(get_sentiment(title_sentiment["compound"]))
        except AttributeError:
            pass

    title_sent_df = pd.DataFrame(title_sent)
    #title_sent_df.head()

    headline_sentiment_df = df.join(title_sent_df)
    headline_sentiment_df.dropna()
    headline_sentiment_df['Date'] = headline_sentiment_df['Date'].str.replace('at','-')
    headline_sentiment_df['Date'] = headline_sentiment_df['Date'].str.split('-').str[0]
    headline_sentiment_df = headline_sentiment_df.reindex(columns=['Date', 'Headline', 'compound', 'positive', 'neutral', 'negative', 'sentiment'])
    headline_sentiment_df['Date'] = pd.to_datetime(headline_sentiment_df['Date'])
    headline_sentiment_df.set_index('Date')
    return headline_sentiment_df

# %%
aapl_headlines = create_sentiment_df(aapl_headlines_df)
amzn_headlines = create_sentiment_df(amzn_headlines_df)
tsla_headlines = create_sentiment_df(tsla_headlines_df)
spy_headlines = create_sentiment_df(spy_headlines_df)
# Out:
#            Date                                           Headline  compound  \
# 0    2020-11-09  Apple Inc. stock falls Monday, underperforms m...    0.0000
# 1    2020-11-09  Big Tech Stocks Are Lagging Today. Why They’ll...   -0.0772
# 2    2020-11-09  As Apple releases its new line of Macs, the bi...    0.4767
# 3    2020-11-06  In the Midst of Election Uncertainty, Younger ...   -0.3400
# 4    2020-11-07  Berkshire Buybacks Hit Record $9 Billion in Th...   -0.1531
# 5    2020-11-03  This single-country stock picker has beaten th...   -0.0258
# 6    2020-11-06  Apple Inc. stock falls Friday, underperforms m...    0.0000
# 7    2020-11-06  T-Mobile Stock Is at a Record High After Earni...    0.0000
# 8    2020-11-06  Dow's 25-point fall led by losses in UnitedHea...   -0.1280
# 9    2020-11-06  Dow falls 110 points on losses for Apple Inc.,...   -0.1280
# 10   2020-11-06  Apple's stock falls 1.2% premarket to pace the...    0.0000
# 11   2020-11-05  Apple Inc. stock outperforms market on strong ...    0.5106
# 12   2020-11-05  Alibaba Stock Is Falling. It’s Time to Pounce ...   -0.1531
# 13   2020-11-05  Dow rallies 463 points on gains for shares of ...    0.5574
# 14   2020-11-04    Why the Election Means the S&P 500 Can Hit 3800    0.0000
# 15   2018-10-28  What Reviewers Are Saying About the New Apple ...    0.0000
# 16   2018-10-22  Apple Could Become a Multibillion-Dollar Ad Bu...    0.0000
# 17   2018-10-08      Apple’s Newest iPhones May Do Better in China    0.4404
# 18   2017-11-20  Never Mind Black Friday; There’s Now an Entire...    0.0000
# 19   2017-09-12  Apple Event: Is There One More Thing? (Updatin...    0.0000
# 20   2020-11-04  Zynga Beat Earnings Expectations. Why Its Stoc...   -0.1531
# 21   2020-11-04  Qualcomm Stock Is Surging. It Wasn’t Just the ...    0.0000
# 22   2020-11-04  Apple could face shortage of critical chips fo...   -0.5106
# 23   2020-11-04  These stocks rose the most Wednesday as invest...    0.5106
# 24   2020-11-04  The Stock Market Doesn’t Seem to Care Who Wins...    0.7845
# 25   2020-11-04  Tech Stocks Soar Amid Vote Uncertainty. Califo...   -0.2500
# 26   2020-11-04  Big Tech exhales: No blue wave allays fears of...   -0.6124
# 27   2020-11-04  Big Tech shares soar as fears of a blue wave s...   -0.1531
# 28   2020-11-04  T-Mobile Reports Earnings Tomorrow. Here’s Wha...    0.0000
# 29   2020-11-03  Apple Inc. stock rises Tuesday, still underper...    0.0000
# ...         ...                                                ...       ...
# 9843 2016-08-30  Republicans and Democrats agree: EU tax case a...    0.3612
# 9844 2016-08-30  Tim Cook says tax issue in Europe is not how m...    0.0000
# 23       0.202    0.798     0.000          1
# 24       0.330    0.670     0.000          1
# 25       0.119    0.678     0.203         -1
# 26       0.000    0.643     0.357         -1
# 27       0.138    0.688     0.175         -1
# 28       0.000    1.000     0.000          0
# 29       0.000    1.000     0.000          0
# ...        ...      ...       ...        ...
# 9843     0.200    0.800     0.000          1
# 9844     0.000    1.000     0.000          0
# 9845     0.000    1.000     0.000          0
# 9846     0.000    1.000     0.000          0
# 9847     0.000    0.783     0.217         -1
# 9848     0.000    1.000     0.000          0
# 9849     0.000    0.780     0.220         -1
# 9850     0.184    0.816     0.000          1
# 9851     0.000    1.000     0.000          0
# 9852     0.000    1.000     0.000          0
# 9853     0.000    1.000     0.000          0
# 9854     0.000    1.000     0.000          0
# 9855     0.000    0.816     0.184         -1
# 9856     0.268    0.732     0.000          1
# 9857     0.000    0.920     0.080         -1
# 9858     0.000    0.845     0.155         -1
# 9859     0.220    0.780     0.000          1
# 9860     0.000    1.000     0.000          0
# 9861     0.000    0.822     0.178         -1
# 9862     0.000    1.000     0.000          0
# 9863     0.000    0.805     0.195         -1
# 9864     0.435    0.565     0.000          1
# 9865     0.000    1.000     0.000          0
# 9866     0.000    0.805     0.195         -1
# 9867     0.000    1.000     0.000          0
# 9868     0.279    0.721     0.000          1
# 9869     0.000    1.000     0.000          0
# 9870     0.209    0.791     0.000          1
# 9871     0.126    0.874     0.000          1
# 9872     0.000    1.000     0.000          0
#
# [9873 rows x 7 columns]

# %%
# find average sentiment score by date
aapl_scores = aapl_headlines.groupby('Date').mean().sort_values(by='Date')
#amzn_scores = amzn_headlines.groupby(['Date']).mean().sort_values(by='Date')
tsla_scores = tsla_headlines.groupby(['Date']).mean().sort_values(by='Date')
spy_scores = spy_headlines.groupby(['Date']).mean().sort_values(by='Date')

# %%
aapl_scores = aapl_scores[['positive', 'neutral', 'negative', 'sentiment']]
#amzn_scores = amzn_scores[['positive', 'neutral', 'negative', 'sentiment']]
tsla_scores = tsla_scores[['positive', 'neutral', 'negative', 'sentiment']]
spy_scores = spy_scores[['positive', 'neutral', 'negative', 'sentiment']]

# %%
# sent scores distribution across each df poss use histogram, calc meanstd, or percentiles 
aapl_complete = pd.concat([aapl_scores,aapl_stock_info], join='outer', axis=1).dropna()
#amzn_complete = pd.concat([amzn_scores,amzn_stock_info], join='outer', axis=1).dropna()
tsla_complete = pd.concat([tsla_scores,tsla_stock_info], join='outer', axis=1).dropna()
spy_complete = pd.concat([spy_scores,spy_stock_info], join='outer', axis=1).dropna()
aapl_complete
# Out:
#             positive   neutral  negative  sentiment     close  pct change
# Date
# 2016-08-30  0.061591  0.883455  0.054955  -0.090909  105.9900   -0.007770
# 2016-08-31  0.070400  0.818600  0.111000  -0.200000  106.1100    0.001132
# 2016-09-01  0.069625  0.897625  0.032750   0.125000  106.7300    0.005843
# 2016-09-02  0.063143  0.845429  0.091429  -0.285714  107.7300    0.009369
# 2016-09-06  0.131750  0.804500  0.063750   0.250000  107.7000   -0.000278
# 2016-09-07  0.096000  0.877000  0.027000   0.250000  108.3700    0.006221
# 2020-10-19  0.265333  0.634667  0.100000   0.333333  116.0000   -0.024882
# 2020-10-20  0.122778  0.804889  0.072333   0.222222  117.5000    0.012931
# 2020-10-21  0.000000  0.875000  0.125000  -0.333333  116.8600   -0.005447
# 2020-10-22  0.028800  0.951400  0.019800   0.000000  115.7737   -0.009296
# 2020-10-23  0.101000  0.704250  0.194500  -0.250000  115.0400   -0.006337
# 2020-10-26  0.067375  0.876875  0.055750   0.000000  115.0600    0.000174
# 2020-10-27  0.019571  0.904714  0.075714  -0.142857  116.5300    0.012776
# 2020-10-28  0.051286  0.797000  0.151714  -0.571429  111.1500   -0.046168
# 2020-10-29  0.169200  0.802550  0.028250   0.550000  114.5200    0.030319
# 2020-10-30  0.071667  0.804167  0.124125  -0.333333  108.9000   -0.049074
# 2020-11-02  0.038600  0.896400  0.065000  -0.200000  108.7700   -0.001194
# 2020-11-03  0.119000  0.842000  0.038833   0.500000  110.3750    0.014756
# 2020-11-04  0.078900  0.800900  0.120300  -0.300000  114.9400    0.041359
# 2020-11-05  0.202333  0.747333  0.050333   0.333333  118.9900    0.035236
# 2020-11-06  0.054833  0.845500  0.099500  -0.500000  118.6850   -0.002563
# 2020-11-09  0.104667  0.848333  0.047000   0.000000  116.3200   -0.019927
#
# [1052 rows x 6 columns]

# %%
apple_test_scores = aapl_headlines.groupby('Date').mean().sort_values(by='Date')
tsla_complete = pd.concat([tsla_scores,tsla_stock_info], join='outer', axis=1).dropna()
aapl_test_complete['predicted pct change'] = aapl_test_complete['pct change'].shift(periods=-1)
aapl_test_complete['SCORE'] = ''

# %%
apple_test_scores = aapl_headlines.groupby('Date').mean().sort_values(by='Date')
aapl_test_complete = pd.concat([apple_test_scores,aapl_stock_info], join='outer', axis=1).dropna()
aapl_test_complete['predicted pct change'] = aapl_test_complete['pct change'].shift(periods=-1)
aapl_test_complete['SCORE'] = ''

# %%
temp = [];
for i in range(round(len(aapl_test_complete['compound']))):
    start = i
    end=(i+1)
    temp.append(aapl_test_complete['compound'][start:end])

# %%
for x in range(0,len(temp)):
    for integer,row in temp[x].iteritems():
        if row >= 0.05:
            aapl_test_complete.set_value(integer,'SCORE',1)
            
        elif (row <= -0.05):
            aapl_test_complete.set_value(integer,'SCORE',-1)
            
        else:
            aapl_test_complete.set_value(integer,'SCORE', 0)
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.

# %%
aapl_test_complete.head()
# Out:
#             compound  positive   neutral  negative  sentiment   close  \
# Date
# 2016-08-30 -0.015205  0.061591  0.883455  0.054955  -0.090909  105.99
# 2016-08-31 -0.043420  0.070400  0.818600  0.111000  -0.200000  106.11
# 2016-09-01  0.009625  0.069625  0.897625  0.032750   0.125000  106.73
# 2016-09-02 -0.087129  0.063143  0.845429  0.091429  -0.285714  107.73
# 2016-09-06  0.093200  0.131750  0.804500  0.063750   0.250000  107.70
#
#             pct change  predicted pct change SCORE
# Date
# 2016-08-30   -0.007770              0.001132     0
# 2016-08-31    0.001132              0.005843     0
# 2016-09-01    0.005843              0.009369     0
# 2016-09-02    0.009369             -0.000278    -1
# 2016-09-06   -0.000278              0.006221     1

# %%
test = aapl_test_complete

# %%
temp2 = [];
test['ACTION'] = ''
for i in range(round(len(test['predicted pct change']))):
    start = i
    end=(i+1)
    temp2.append(test['predicted pct change'][start:end])
    
    

for x in range(0,len(temp2)):
    for integer,row in temp2[x].iteritems():
        if row >0:
            test.set_value(integer,'ACTION','ADD MONEY')
            
        elif (row==0):
            test.set_value(integer,'ACTION','HOLD')
            
        else:
            test.set_value(integer,'ACTION', 'TAKE MONEY OUT')
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()

# %%
test[test['ACTION'] == 'HOLD']
# Out:
#             compound  positive  neutral  negative  sentiment   close  \
# Date
# 2018-08-21  0.140280    0.1322  0.83740   0.03040       0.20  215.06
# 2019-09-05  0.073900    0.0696  0.90260   0.02780       0.20  213.27
# 2019-10-29 -0.092375    0.0000  0.93225   0.06775      -0.25  243.29
#
#             pct change  predicted pct change SCORE ACTION
# Date
# 2018-08-21   -0.001810                   0.0     1   HOLD
# 2019-09-05    0.019211                   0.0     1   HOLD
# 2019-10-29   -0.023089                   0.0    -1   HOLD

# %%
test = test.reset_index()
del test['Date']

# %%
def window_data(df, window, feature_col_number, target_col_number):
    """
    This function accepts the column number for the features (X) and the target (y).
    It chunks the data up with a rolling window of Xt - window to predict Xt.
    It returns two numpy arrays of X and y.
    """
    X = []
    y = []
    for i in range(len(df) - window):
        features = df.iloc[i : (i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Define the window size
window_size = 1

# Set the index of the feature and target columns
feature_column = 9
target_column = 9

# Create the features (X) and target (y) data using the window_data() function.
X, y = window_data(test, window_size, feature_column, target_column)

# Print a few sample values from X and y
print (f"X sample values:\n{X[:3]} \n")
print (f"y sample values:\n{y[:3]}")
# Out:
# X sample values:
# [[1]
#  [1]
#  [1]]
#
# y sample values:
# [[ 1]
#  [ 1]
#  [-1]]

# %%
# Manually splitting the data
split = int(0.7 * len(X))

X_train = X[: split]
X_test = X[split:]

y_train = y[: split]
y_test = y[split:]

# %%
# Importing the MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the MinMaxScaler object with the features data X
scaler.fit(X)

# Scale the features training and testing sets
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Fit the MinMaxScaler object with the target data Y
scaler.fit(y)

# Scale the target training and testing sets
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features data
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Print some sample data after reshaping the datasets
print (f"X_train sample values:\n{X_train[:3]} \n")
print (f"X_test sample values:\n{X_test[:3]}")
# Out:
# X_train sample values:
# [[[1.]]
#
#  [[1.]]
#
#  [[1.]]]
#
# X_test sample values:
# [[[0.]]
#
#  [[1.]]
#
#  [[0.]]]

# %%
# Importing required Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define the LSTM RNN model.
model = Sequential()

# Initial model setup
number_units = 1
dropout_fraction = 0.2

# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))

# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))

# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))

model.add(Dense(units=1, activation='relu'))
model.add(Dense(units=1, activation='relu'))
model.add(Dense(units=1, activation='relu'))
model.add(Dense(units=1, activation='relu'))
model.add(Dense(units=1, activation='relu'))

# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss="mean_squared_error",metrics=['accuracy'])

# %%
# Show the model summary
model.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_32 (LSTM)               (None, 1, 1)              12
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 1, 1)              0
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 1, 1)              12
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 1, 1)              0
# _________________________________________________________________
# lstm_34 (LSTM)               (None, 1)                 12
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 1)                 0
# _________________________________________________________________
# dense_113 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_114 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_115 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_116 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_117 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_118 (Dense)            (None, 1)                 2
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(X_train, y_train, epochs=300, shuffle=False, batch_size=90, verbose=1)
# Out:
# Epoch 1/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2676 - accuracy: 0.4639
# Epoch 2/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.4639
# Epoch 3/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2655 - accuracy: 0.4639
# Epoch 4/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.4639
# Epoch 5/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.4639
# Epoch 6/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2628 - accuracy: 0.4639
# Epoch 7/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.4639
# Epoch 8/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.4639
# Epoch 9/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.4639
# Epoch 10/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2597 - accuracy: 0.4639
# Epoch 11/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2590 - accuracy: 0.4639
# Epoch 12/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.4639
# Epoch 13/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.4639
# Epoch 14/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2572 - accuracy: 0.4639
# Epoch 15/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2567 - accuracy: 0.4639
# Epoch 16/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.4639
# Epoch 17/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2557 - accuracy: 0.4639
# Epoch 18/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2553 - accuracy: 0.4639
# Epoch 19/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.4639
# Epoch 20/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.4639
# Epoch 21/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.4639
# Epoch 22/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.4639
# Epoch 23/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.4639
# Epoch 24/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.4639
# Epoch 25/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.4639
# Epoch 26/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2525 - accuracy: 0.4639
# Epoch 27/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.4639
# Epoch 28/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.4639
# Epoch 29/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.4639
# Epoch 30/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.4639
# Epoch 31/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.4639
# Epoch 32/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.4639
# Epoch 33/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.4639
# Epoch 34/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.4639
# Epoch 35/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.4639
# Epoch 36/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.4639
# Epoch 37/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.4639
# Epoch 38/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.4639
# Epoch 39/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.4639
# Epoch 40/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.4639
# Epoch 41/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.4639
# Epoch 42/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.4639
# Epoch 43/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.4912
# Epoch 44/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.5347
# Epoch 45/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5347
# Epoch 46/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5347
# Epoch 47/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5347
# Epoch 48/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5347
# Epoch 49/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5347
# Epoch 50/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5347
# Epoch 51/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5347
# Epoch 52/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5347
# Epoch 53/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5347
# Epoch 54/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5347
# Epoch 55/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5347
# Epoch 56/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5347
# Epoch 57/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5347
# Epoch 58/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5347
# Epoch 59/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5347
# Epoch 60/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5347
# Epoch 61/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5347
# Epoch 62/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5347
# Epoch 63/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5347
# Epoch 64/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5347
# Epoch 65/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5347
# Epoch 66/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5347
# Epoch 67/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5347
# Epoch 68/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.5347
# Epoch 69/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 70/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 71/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 72/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 73/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 74/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 75/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 76/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 77/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 78/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.5347
# Epoch 79/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 80/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 81/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 82/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 83/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 84/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 85/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 86/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 87/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 88/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 89/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 90/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 91/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 92/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 93/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 94/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 95/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 96/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 97/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 98/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 99/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 100/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 101/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 102/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 103/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 104/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 105/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 106/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 107/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 108/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 109/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 110/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 111/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 112/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 113/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 114/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 115/300
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 116/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 117/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 118/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 119/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 120/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 121/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 122/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 123/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 124/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 125/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 126/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 127/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 128/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 129/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 130/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 131/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 132/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 133/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 134/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 135/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 136/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 137/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 138/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 139/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 140/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 141/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 142/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 143/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 144/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 145/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 146/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 147/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 148/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 149/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 150/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 151/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 152/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 153/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 154/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 155/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 156/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 157/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 158/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 159/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 160/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 161/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 162/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 163/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 164/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 165/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 166/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 167/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 168/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 169/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 170/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 171/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 172/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 173/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 174/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 175/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 176/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 177/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 178/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 179/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 180/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 181/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 182/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 183/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 184/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 185/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 186/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 187/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 188/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 189/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 190/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 191/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 192/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 193/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 194/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 195/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 196/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 197/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 198/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 199/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 200/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 201/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 202/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 203/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 204/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 205/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 206/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 207/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 208/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 209/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 210/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 211/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 212/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 213/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 214/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 215/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 216/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 217/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 218/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 219/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 220/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 221/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 222/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 223/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 224/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 225/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 226/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 227/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 228/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 229/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 230/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 231/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 232/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 233/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 234/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 235/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 236/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 237/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 238/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 239/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 240/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 241/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 242/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 243/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 244/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 245/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 246/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 247/300
# 9/9 [==============================] - 0s 1ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 248/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 249/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 250/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 251/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 252/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 253/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 254/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 255/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 256/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 257/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 258/300
# 9/9 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.58 - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 259/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 260/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 261/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 262/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 263/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 264/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 265/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 266/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 267/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 268/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 269/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 270/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 271/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 272/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 273/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 274/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 275/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 276/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 277/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 278/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 279/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 280/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 281/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 282/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 283/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 284/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 285/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 286/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 287/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 288/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 289/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 290/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 291/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 292/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 293/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 294/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 295/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 296/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 297/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 298/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 299/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347
# Epoch 300/300
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5347

# %%
# Evaluate the model
model_loss, model_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Normal Neural Network - Loss: 0.24522481858730316, Accuracy: 0.5664557218551636

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Make predictions using the testing data X_test
predicted = model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
stocks = pd.DataFrame({
    "Actual": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
}, index = test.index[-len(real_prices): ]) 

# Show the DataFrame's head
stocks.head()
# Out:
#             Actual  Predicted
# Date
# 2019-08-12     1.0  -0.053317
# 2019-08-13    -1.0  -0.028901
# 2019-08-14    -1.0  -0.053317
# 2019-08-15     1.0  -0.053317
# 2019-08-16     1.0  -0.028901

# %%
apple_test_scores.head()
# Out:
#             compound  positive   neutral  negative  sentiment
# Date
# 2016-03-19  0.836000  0.530000  0.470000  0.000000   1.000000
# 2016-08-27  0.038600  0.063000  0.937000  0.000000   0.500000
# 2016-08-28  0.440400  0.209000  0.791000  0.000000   1.000000
# 2016-08-29  0.067100  0.102000  0.842286  0.055714   0.000000
# 2016-08-30 -0.015205  0.061591  0.883455  0.054955  -0.090909

# %%
aapl_test_complete
# Out:
#             compound  positive   neutral  negative  sentiment     close  \
# Date
# 2016-08-30 -0.015205  0.061591  0.883455  0.054955  -0.090909  105.9900
# 2016-08-31 -0.043420  0.070400  0.818600  0.111000  -0.200000  106.1100
# 2016-09-01  0.009625  0.069625  0.897625  0.032750   0.125000  106.7300
# 2016-09-02 -0.087129  0.063143  0.845429  0.091429  -0.285714  107.7300
# 2016-09-06  0.093200  0.131750  0.804500  0.063750   0.250000  107.7000
# 2016-09-07  0.088762  0.096000  0.877000  0.027000   0.250000  108.3700
# 2016-09-08  0.010821  0.069714  0.862357  0.067929   0.000000  105.5100
# 2016-09-09 -0.059275  0.049500  0.872750  0.077750  -0.250000  103.1400
# 2016-09-12  0.158900  0.113000  0.887000  0.000000   0.333333  105.4400
# 2016-09-13  0.079327  0.089818  0.888455  0.021818   0.272727  108.0200
# 2016-09-14 -0.017447  0.061684  0.851000  0.087316  -0.157895  111.7700
# 2016-09-15  0.198892  0.126500  0.873500  0.000000   0.333333  115.5700
# 2016-09-16  0.024600  0.094000  0.847727  0.058273   0.181818  114.9100
# 2020-10-07    0.016702             -0.000695     0  TAKE MONEY OUT
# 2020-10-08   -0.000695              0.017483     1       ADD MONEY
# 2020-10-09    0.017483              0.063601     0       ADD MONEY
# 2020-10-12    0.063601             -0.027086     1  TAKE MONEY OUT
# 2020-10-13   -0.027086              0.001983     0       ADD MONEY
# 2020-10-14    0.001983             -0.004491     1  TAKE MONEY OUT
# 2020-10-15   -0.004491             -0.014786     1  TAKE MONEY OUT
# 2020-10-16   -0.014786             -0.024882    -1  TAKE MONEY OUT
# 2020-10-19   -0.024882              0.012931     1       ADD MONEY
# 2020-10-20    0.012931             -0.005447     1  TAKE MONEY OUT
# 2020-10-21   -0.005447             -0.009296    -1  TAKE MONEY OUT
# 2020-10-22   -0.009296             -0.006337     0  TAKE MONEY OUT
# 2020-10-23   -0.006337              0.000174    -1       ADD MONEY
# 2020-10-26    0.000174              0.012776     0       ADD MONEY
# 2020-10-27    0.012776             -0.046168    -1  TAKE MONEY OUT
# 2020-10-28   -0.046168              0.030319    -1       ADD MONEY
# 2020-10-29    0.030319             -0.049074     1  TAKE MONEY OUT
# 2020-10-30   -0.049074             -0.001194    -1  TAKE MONEY OUT
# 2020-11-02   -0.001194              0.014756    -1       ADD MONEY
# 2020-11-03    0.014756              0.041359     1       ADD MONEY
# 2020-11-04    0.041359              0.035236     0       ADD MONEY
# 2020-11-05    0.035236             -0.002563     1  TAKE MONEY OUT
# 2020-11-06   -0.002563             -0.019927    -1  TAKE MONEY OUT
# 2020-11-09   -0.019927                   NaN     1  TAKE MONEY OUT
#
# [1052 rows x 10 columns]

# %%
apple_test_scores = aapl_headlines.groupby('Date').mean().sort_values(by='Date')
aapl_test_complete = pd.concat([apple_test_scores,aapl_stock_info], join='outer', axis=1).dropna()
aapl_test_complete['predicted pct change'] = aapl_test_complete['pct change'].shift(periods=-1)
aapl_test_complete['SCORE'] = ''

# %%
tsla_test_scores = tsla_headlines.groupby('Date').mean().sort_values(by='Date')
tsla_test_complete = pd.concat([tsla_test_scores,tsla_stock_info], join='outer', axis=1).dropna()
tsla_test_complete['predicted pct change'] = tsla_test_complete['pct change'].shift(periods=-1)
tsla_test_complete['SCORE'] = ''

# %%
temp = [];
for i in range(round(len(aapl_test_complete['compound']))):
    start = i
    end=(i+1)
    temp.append(aapl_test_complete['compound'][start:end])

# %%
#APPLE

for x in range(0,len(temp)):
    for integer,row in temp[x].iteritems():
        if row >= 0.05:
            aapl_test_complete.set_value(integer,'SCORE',1)
            
        elif (row <= -0.05):
            aapl_test_complete.set_value(integer,'SCORE',-1)
            
        else:
            aapl_test_complete.set_value(integer,'SCORE', 0)
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
#TESLA
temp = [];
for i in range(round(len(tsla_test_complete['compound']))):
    start = i
    end=(i+1)
    temp.append(tsla_test_complete['compound'][start:end])


for x in range(0,len(temp)):
    for integer,row in temp[x].iteritems():
        if row >= 0.05:
            tsla_test_complete.set_value(integer,'SCORE',1)
            
        elif (row <= -0.05):
            tsla_test_complete.set_value(integer,'SCORE',-1)
            
        else:
            tsla_test_complete.set_value(integer,'SCORE', 0)
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app

# %%
test2 = tsla_test_complete

# %%
test2.head()
# Out:
#             compound  positive   neutral  negative  sentiment   close  \
# Date
# 2016-08-30   0.00000  0.000000  1.000000    0.0000   0.000000  211.34
# 2016-08-31   0.09955  0.086333  0.891167    0.0225   0.166667  211.95
# 2016-09-01   0.19020  0.170500  0.829500    0.0000   0.500000  200.77
# 2016-09-02   0.01680  0.101333  0.801000    0.0980   0.000000  197.78
# 2016-09-07  -0.40190  0.175000  0.485000    0.3400  -1.000000  201.70
#
#             pct change  predicted pct change SCORE ACTION
# Date
# 2016-08-30   -0.017937              0.002886     0      1
# 2016-08-31    0.002886             -0.052748     1      0
# 2016-09-01   -0.052748             -0.014893     1      0
# 2016-09-02   -0.014893             -0.005522     0      0
# 2016-09-07   -0.005522             -0.020873    -1      0

# %%
#TESLA
temp2 = [];
test2['ACTION'] = ''
for i in range(round(len(test2['predicted pct change']))):
    start = i
    end=(i+1)
    temp2.append(test2['predicted pct change'][start:end])
    
    

for x in range(0,len(temp2)):
    for integer,row in temp2[x].iteritems():
        if row >0:
            test2.set_value(integer,'ACTION',1)
            
        elif (row==0):
            test2.set_value(integer,'ACTION',1)
            
        else:
            test2.set_value(integer,'ACTION', 0)
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
test = aapl_test_complete

# %%
temp2 = [];
test['ACTION'] = ''
for i in range(round(len(test['predicted pct change']))):
    start = i
    end=(i+1)
    temp2.append(test['predicted pct change'][start:end])
    
    

for x in range(0,len(temp2)):
    for integer,row in temp2[x].iteritems():
        if row >0:
            test.set_value(integer,'ACTION',1)
            
        elif (row==0):
            test.set_value(integer,'ACTION',1)
            
        else:
            test.set_value(integer,'ACTION', 0)
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\godz7\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()

# %%
test = test.dropna()

# %%
del aapl_test_complete['Date']

# %%
test = test.reset_index()
del test['Date']

# %%
del test['pct change']
test.head()
# Out:
#             compound  positive   neutral  negative  sentiment   close  \
# Date
# 2016-08-30 -0.015205  0.061591  0.883455  0.054955  -0.090909  105.99
# 2016-08-31 -0.043420  0.070400  0.818600  0.111000  -0.200000  106.11
# 2016-09-01  0.009625  0.069625  0.897625  0.032750   0.125000  106.73
# 2016-09-02 -0.087129  0.063143  0.845429  0.091429  -0.285714  107.73
# 2016-09-06  0.093200  0.131750  0.804500  0.063750   0.250000  107.70
#
#             predicted pct change SCORE ACTION
# Date
# 2016-08-30              0.001132     0      1
# 2016-08-31              0.005843     0      1
# 2016-09-01              0.009369     0      1
# 2016-09-02             -0.000278    -1      0
# 2016-09-06              0.006221     1      1

# %%
test
# Out:
#             compound  positive   neutral  negative  sentiment     close  \
# Date
# 2016-08-30 -0.015205  0.061591  0.883455  0.054955  -0.090909  105.9900
# 2016-08-31 -0.043420  0.070400  0.818600  0.111000  -0.200000  106.1100
# 2016-09-01  0.009625  0.069625  0.897625  0.032750   0.125000  106.7300
# 2016-09-02 -0.087129  0.063143  0.845429  0.091429  -0.285714  107.7300
# 2016-09-06  0.093200  0.131750  0.804500  0.063750   0.250000  107.7000
# 2020-10-15  0.059656  0.105444  0.815333  0.079222  -0.111111  120.7453
# 2020-10-16 -0.144840  0.015600  0.904800  0.079600  -0.600000  118.9600
# 2020-10-19  0.228733  0.265333  0.634667  0.100000   0.333333  116.0000
# 2020-10-20  0.091967  0.122778  0.804889  0.072333   0.222222  117.5000
# 2020-10-21 -0.219900  0.000000  0.875000  0.125000  -0.333333  116.8600
# 2020-10-22  0.006620  0.028800  0.951400  0.019800   0.000000  115.7737
# 2020-10-23 -0.163150  0.101000  0.704250  0.194500  -0.250000  115.0400
# 2020-10-26 -0.008588  0.067375  0.876875  0.055750   0.000000  115.0600
# 2020-10-27 -0.078186  0.019571  0.904714  0.075714  -0.142857  116.5300
# 2020-10-28 -0.208286  0.051286  0.797000  0.151714  -0.571429  111.1500
# 2020-10-29  0.234180  0.169200  0.802550  0.028250   0.550000  114.5200
# 2020-10-30 -0.106842  0.071667  0.804167  0.124125  -0.333333  108.9000
# 2020-11-02 -0.102360  0.038600  0.896400  0.065000  -0.200000  108.7700
# 2020-11-03  0.181500  0.119000  0.842000  0.038833   0.500000  110.3750
# 2020-11-04 -0.038410  0.078900  0.800900  0.120300  -0.300000  114.9400
# 2020-11-05  0.304967  0.202333  0.747333  0.050333   0.333333  118.9900
# 2020-11-06 -0.099333  0.054833  0.845500  0.099500  -0.500000  118.6850
#
#             predicted pct change SCORE          ACTION
# Date
# 2016-08-30              0.001132     0       ADD MONEY
# 2016-08-31              0.005843     0       ADD MONEY
# 2016-09-01              0.009369     0       ADD MONEY
# 2016-09-02             -0.000278    -1  TAKE MONEY OUT
# 2016-09-06              0.006221     1       ADD MONEY
# 2016-09-07             -0.026391     1  TAKE MONEY OUT
# 2016-09-08             -0.022462     0  TAKE MONEY OUT
# 2016-09-09              0.022300    -1       ADD MONEY
# 2016-09-12              0.024469     1       ADD MONEY
# 2016-09-13              0.034716     1       ADD MONEY
# 2016-09-14              0.033998     0       ADD MONEY
# 2016-09-15             -0.005711     1  TAKE MONEY OUT
# 2016-09-16             -0.012009     0  TAKE MONEY OUT
# 2016-09-19              0.000352     1       ADD MONEY
# 2016-09-20             -0.000352     1  TAKE MONEY OUT
# 2016-09-21              0.009513    -1       ADD MONEY
# 2016-09-22             -0.016622     0  TAKE MONEY OUT
# 2016-09-23              0.001465     1       ADD MONEY
# 2016-09-26              0.002126     1       ADD MONEY
# 2016-09-27              0.007426     0       ADD MONEY
# 2016-09-28             -0.015533     1  TAKE MONEY OUT
# 2016-09-29              0.007577    -1       ADD MONEY
# 2016-09-30             -0.004601    -1  TAKE MONEY OUT
# 2016-10-03              0.004533     0       ADD MONEY
# 2016-10-04              0.000177    -1       ADD MONEY
# 2016-10-05              0.007696     1       ADD MONEY
# 2016-10-06              0.001053     0       ADD MONEY
# 2016-10-07              0.017715     1       ADD MONEY
# 2016-10-10              0.002499     1       ADD MONEY
# 2016-10-11              0.008681     1       ADD MONEY
# ...                          ...   ...             ...
# 2020-09-28             -0.007739     0  TAKE MONEY OUT
# 2020-09-29              0.013145     1       ADD MONEY
# 2020-09-30              0.010293     0       ADD MONEY
# 2020-10-01             -0.032363     0  TAKE MONEY OUT
# 2020-10-02              0.031145    -1       ADD MONEY
# 2020-10-05             -0.029003     1  TAKE MONEY OUT
# 2020-10-06              0.016702     0       ADD MONEY
# 2020-10-07             -0.000695     0  TAKE MONEY OUT
# 2020-10-08              0.017483     1       ADD MONEY
# 2020-10-09              0.063601     0       ADD MONEY
# 2020-10-12             -0.027086     1  TAKE MONEY OUT
# 2020-10-13              0.001983     0       ADD MONEY
# 2020-10-14             -0.004491     1  TAKE MONEY OUT
# 2020-10-15             -0.014786     1  TAKE MONEY OUT
# 2020-10-16             -0.024882    -1  TAKE MONEY OUT
# 2020-10-19              0.012931     1       ADD MONEY
# 2020-10-20             -0.005447     1  TAKE MONEY OUT
# 2020-10-21             -0.009296    -1  TAKE MONEY OUT
# 2020-10-22             -0.006337     0  TAKE MONEY OUT
# 2020-10-23              0.000174    -1       ADD MONEY
# 2020-10-26              0.012776     0       ADD MONEY
# 2020-10-27             -0.046168    -1  TAKE MONEY OUT
# 2020-10-28              0.030319    -1       ADD MONEY
# 2020-10-29             -0.049074     1  TAKE MONEY OUT
# 2020-10-30             -0.001194    -1  TAKE MONEY OUT
# 2020-11-02              0.014756    -1       ADD MONEY
# 2020-11-03              0.041359     1       ADD MONEY
# 2020-11-04              0.035236     0       ADD MONEY
# 2020-11-05             -0.002563     1  TAKE MONEY OUT
# 2020-11-06             -0.019927    -1  TAKE MONEY OUT
#
# [1051 rows x 9 columns]

# %%
X = test.drop("ACTION", axis=1)
y = test["ACTION"]
print(X.shape, y.shape)
# Out:
# (1051, 8) (1051,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1, stratify=y)
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=8))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 25/25 - 0s - loss: 0.8679 - accuracy: 0.6117
# Epoch 2/100
# 25/25 - 0s - loss: 0.5554 - accuracy: 0.8490
# Epoch 3/100
# 25/25 - 0s - loss: 0.4043 - accuracy: 0.9010
# Epoch 4/100
# 25/25 - 0s - loss: 0.2921 - accuracy: 0.9404
# Epoch 5/100
# 25/25 - 0s - loss: 0.2278 - accuracy: 0.9467
# Epoch 6/100
# 25/25 - 0s - loss: 0.1783 - accuracy: 0.9645
# Epoch 7/100
# 25/25 - 0s - loss: 0.1475 - accuracy: 0.9734
# Epoch 8/100
# 25/25 - 0s - loss: 0.1285 - accuracy: 0.9759
# Epoch 9/100
# 25/25 - 0s - loss: 0.1129 - accuracy: 0.9708
# Epoch 10/100
# 25/25 - 0s - loss: 0.1011 - accuracy: 0.9746
# Epoch 11/100
# 25/25 - 0s - loss: 0.0894 - accuracy: 0.9772
# Epoch 12/100
# 25/25 - 0s - loss: 0.0792 - accuracy: 0.9860
# Epoch 13/100
# 25/25 - 0s - loss: 0.0755 - accuracy: 0.9835
# Epoch 14/100
# 25/25 - 0s - loss: 0.0668 - accuracy: 0.9886
# Epoch 15/100
# 25/25 - 0s - loss: 0.0658 - accuracy: 0.9848
# Epoch 16/100
# 25/25 - 0s - loss: 0.0576 - accuracy: 0.9911
# Epoch 17/100
# 25/25 - 0s - loss: 0.0579 - accuracy: 0.9860
# Epoch 18/100
# 25/25 - 0s - loss: 0.0522 - accuracy: 0.9886
# Epoch 19/100
# 25/25 - 0s - loss: 0.0513 - accuracy: 0.9860
# Epoch 20/100
# 25/25 - 0s - loss: 0.0517 - accuracy: 0.9873
# Epoch 21/100
# 25/25 - 0s - loss: 0.0510 - accuracy: 0.9835
# Epoch 22/100
# 25/25 - 0s - loss: 0.0411 - accuracy: 0.9937
# Epoch 23/100
# 25/25 - 0s - loss: 0.0393 - accuracy: 0.9924
# Epoch 24/100
# 25/25 - 0s - loss: 0.0435 - accuracy: 0.9860
# Epoch 25/100
# 25/25 - 0s - loss: 0.0418 - accuracy: 0.9898
# Epoch 26/100
# 25/25 - 0s - loss: 0.0361 - accuracy: 0.9924
# Epoch 27/100
# 25/25 - 0s - loss: 0.0352 - accuracy: 0.9924
# Epoch 28/100
# 25/25 - 0s - loss: 0.0324 - accuracy: 0.9949
# Epoch 29/100
# 25/25 - 0s - loss: 0.0278 - accuracy: 0.9975
# Epoch 30/100
# 25/25 - 0s - loss: 0.0298 - accuracy: 0.9949
# Epoch 31/100
# 25/25 - 0s - loss: 0.0298 - accuracy: 0.9949
# Epoch 32/100
# 25/25 - 0s - loss: 0.0272 - accuracy: 0.9949
# Epoch 33/100
# 25/25 - 0s - loss: 0.0271 - accuracy: 0.9949
# Epoch 34/100
# 25/25 - 0s - loss: 0.0268 - accuracy: 0.9911
# Epoch 35/100
# 25/25 - 0s - loss: 0.0304 - accuracy: 0.9924
# Epoch 36/100
# 25/25 - 0s - loss: 0.0245 - accuracy: 0.9949
# Epoch 37/100
# 25/25 - 0s - loss: 0.0225 - accuracy: 0.9962
# Epoch 38/100
# 25/25 - 0s - loss: 0.0204 - accuracy: 0.9962
# Epoch 39/100
# 25/25 - 0s - loss: 0.0191 - accuracy: 0.9975
# Epoch 40/100
# 25/25 - 0s - loss: 0.0199 - accuracy: 0.9975
# Epoch 41/100
# 25/25 - 0s - loss: 0.0210 - accuracy: 0.9962
# Epoch 42/100
# 25/25 - 0s - loss: 0.0177 - accuracy: 0.9975
# Epoch 43/100
# 25/25 - 0s - loss: 0.0170 - accuracy: 0.9975
# Epoch 44/100
# 25/25 - 0s - loss: 0.0170 - accuracy: 0.9975
# Epoch 45/100
# 25/25 - 0s - loss: 0.0216 - accuracy: 0.9937
# Epoch 46/100
# 25/25 - 0s - loss: 0.0183 - accuracy: 0.9937
# Epoch 47/100
# 25/25 - 0s - loss: 0.0206 - accuracy: 0.9937
# Epoch 48/100
# 25/25 - 0s - loss: 0.0158 - accuracy: 0.9975
# Epoch 49/100
# 25/25 - 0s - loss: 0.0158 - accuracy: 0.9962
# Epoch 50/100
# 25/25 - 0s - loss: 0.0151 - accuracy: 0.9975
# Epoch 51/100
# 25/25 - 0s - loss: 0.0154 - accuracy: 0.9949
# Epoch 52/100
# 25/25 - 0s - loss: 0.0159 - accuracy: 0.9962
# Epoch 53/100
# 25/25 - 0s - loss: 0.0148 - accuracy: 0.9962
# Epoch 54/100
# 25/25 - 0s - loss: 0.0133 - accuracy: 0.9975
# Epoch 55/100
# 25/25 - 0s - loss: 0.0147 - accuracy: 0.9949
# Epoch 56/100
# 25/25 - 0s - loss: 0.0135 - accuracy: 0.9949
# Epoch 57/100
# 25/25 - 0s - loss: 0.0107 - accuracy: 0.9987
# Epoch 58/100
# 25/25 - 0s - loss: 0.0108 - accuracy: 0.9975
# Epoch 59/100
# 25/25 - 0s - loss: 0.0099 - accuracy: 0.9975
# Epoch 60/100
# 25/25 - 0s - loss: 0.0123 - accuracy: 0.9987
# Epoch 61/100
# 25/25 - 0s - loss: 0.0164 - accuracy: 0.9937
# Epoch 62/100
# 25/25 - 0s - loss: 0.0192 - accuracy: 0.9911
# Epoch 63/100
# 25/25 - 0s - loss: 0.0278 - accuracy: 0.9886
# Epoch 64/100
# 25/25 - 0s - loss: 0.0136 - accuracy: 0.9975
# Epoch 65/100
# 25/25 - 0s - loss: 0.0101 - accuracy: 0.9987
# Epoch 66/100
# 25/25 - 0s - loss: 0.0091 - accuracy: 0.9987
# Epoch 67/100
# 25/25 - 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 68/100
# 25/25 - 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 69/100
# 25/25 - 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 70/100
# 25/25 - 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 71/100
# 25/25 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 72/100
# 25/25 - 0s - loss: 0.0078 - accuracy: 1.0000
# Epoch 73/100
# 25/25 - 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 74/100
# 25/25 - 0s - loss: 0.0085 - accuracy: 0.9987
# Epoch 75/100
# 25/25 - 0s - loss: 0.0146 - accuracy: 0.9962
# Epoch 76/100
# 25/25 - 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 77/100
# 25/25 - 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 78/100
# 25/25 - 0s - loss: 0.0108 - accuracy: 0.9987
# Epoch 79/100
# 25/25 - 0s - loss: 0.0091 - accuracy: 0.9987
# Epoch 80/100
# 25/25 - 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 81/100
# 25/25 - 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 82/100
# 25/25 - 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 83/100
# 25/25 - 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 84/100
# 25/25 - 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 85/100
# 25/25 - 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 86/100
# 25/25 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 87/100
# 25/25 - 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 88/100
# 25/25 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 89/100
# 25/25 - 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 90/100
# 25/25 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 91/100
# 25/25 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 92/100
# 25/25 - 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 93/100
# 25/25 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 94/100
# 25/25 - 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 95/100
# 25/25 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 96/100
# 25/25 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 97/100
# 25/25 - 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 98/100
# 25/25 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 99/100
# 25/25 - 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 100/100
# 25/25 - 0s - loss: 0.0031 - accuracy: 1.0000

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 9/9 - 0s - loss: 0.1458 - accuracy: 0.9620
# Normal Neural Network - Loss: 0.14584596455097198, Accuracy: 0.9619771838188171

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000238F497E400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['TAKE MONEY OUT' 'TAKE MONEY OUT' 'ADD MONEY' 'TAKE MONEY OUT'
#  'TAKE MONEY OUT']
# Actual Labels: ['TAKE MONEY OUT', 'TAKE MONEY OUT', 'ADD MONEY', 'TAKE MONEY OUT', 'TAKE MONEY OUT']

# %%
apple_score_test = aapl_scores.reset_index()
apple_score_test['Date'] = apple_score_test['Date'].astype(str)

apple_stock_test = aapl_stock_info.reset_index()
apple_stock_test['Date'] = apple_stock_test['Date'].astype(str)

# %%
test2
# Out:
#             compound  positive   neutral  negative  sentiment     close  \
# Date
# 2016-08-30  0.000000  0.000000  1.000000  0.000000   0.000000  211.3400
# 2016-09-26     1      1
# 2016-09-27     0      1
# 2016-09-28     1      0
# 2016-09-29    -1      1
# 2016-09-30    -1      0
# 2016-10-03     0      1
# 2016-10-04    -1      1
# 2016-10-05     1      1
# 2016-10-06     0      1
# 2016-10-07     1      1
# 2016-10-10     1      1
# 2016-10-11     1      1
# ...          ...    ...
# 2020-09-28     0      0
# 2020-09-29     1      1
# 2020-09-30     0      1
# 2020-10-01     0      0
# 2020-10-02    -1      1
# 2020-10-05     1      0
# 2020-10-06     0      1
# 2020-10-07     0      0
# 2020-10-08     1      1
# 2020-10-09     0      1
# 2020-10-12     1      0
# 2020-10-13     0      1
# 2020-10-14     1      0
# 2020-10-15     1      0
# 2020-10-16    -1      0
# 2020-10-19     1      1
# 2020-10-20     1      0
# 2020-10-21    -1      0
# 2020-10-22     0      0
# 2020-10-23    -1      1
# 2020-10-26     0      1
# 2020-10-27    -1      0
# 2020-10-28    -1      1
# 2020-10-29     1      0
# 2020-10-30    -1      0
# 2020-11-02    -1      1
# 2020-11-03     1      1
# 2020-11-04     0      1
# 2020-11-05     1      0
# 2020-11-06    -1      0
#
# [1051 rows x 2 columns]

# %%
target = test2["ACTION"].astype(int)
target_names = ["negative", "positive"]

# %%
test2.head()
# Out:
#             compound  positive   neutral  negative  sentiment   close  \
# Date
# 2016-08-30   0.00000  0.000000  1.000000    0.0000   0.000000  211.34
# 2016-08-31   0.09955  0.086333  0.891167    0.0225   0.166667  211.95
# 2016-09-01   0.19020  0.170500  0.829500    0.0000   0.500000  200.77
# 2016-09-02   0.01680  0.101333  0.801000    0.0980   0.000000  197.78
# 2016-09-07  -0.40190  0.175000  0.485000    0.3400  -1.000000  201.70
#
#             pct change  predicted pct change SCORE ACTION
# Date
# 2016-08-30   -0.017937              0.002886     0      1
# 2016-08-31    0.002886             -0.052748     1      0
# 2016-09-01   -0.052748             -0.014893     1      0
# 2016-09-02   -0.014893             -0.005522     0      0
# 2016-09-07   -0.005522             -0.020873    -1      0

# %%
test2=test2.reset_index()
test2 = test2[['compound','SCORE','ACTION']]
data = test2.drop("ACTION", axis=1).dropna()
feature_names = data.columns
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-563-89a53ae1aee0> in <module>
#       1 test2=test2.reset_index()
# ----> 2 test2 = test2[['compound','SCORE','ACTION']]
#       3 data = test2.drop("ACTION", axis=1).dropna()
#       4 feature_names = data.columns
#       5 data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['compound'] not in index"

# %%
data.columns
# Out:
# Index(['Date', 'SCORE'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='sigmoid')
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-562-d968daddcdc0> in <module>
#       2 from sklearn.svm import SVC
#       3 model = SVC(kernel='rbf')
# ----> 4 model.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     144         X, y = check_X_y(X, y, dtype=np.float64,
#     145                          order='C', accept_sparse='csr',
# --> 146                          accept_large_sparse=False)
#     147         y = self._validate_targets(y)
#     148
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.517

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.24      0.32       126
#     positive       0.52      0.78      0.62       135
#
#     accuracy                           0.52       261
#    macro avg       0.51      0.51      0.47       261
# weighted avg       0.51      0.52      0.48       261
