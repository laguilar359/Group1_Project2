# %%
from splinter import Browser
import pandas as pd
import numpy as np

# %%
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
d = {'Headline': [], 'Date': []}
df = pd.DataFrame(data=d)

# %%
for x in range(0,500):
    url = f"https://www.marketwatch.com/investing/stock/AAPL/moreheadlines?channel=MarketWatch&pageNumber={x}"
    browser.visit(url)
    for y in range(0,len(browser.find_by_css('h3[class="article__headline"]'))):
        df = df.append({'Headline':browser.find_by_css('h3[class="article__headline"]')[y].text,
                        'Date':browser.find_by_css('span[class="article__timestamp"]')[y].text},ignore_index=True)

# %%
url = f"https://www.marketwatch.com/investing/stock/AAPL/moreheadlines?channel=MarketWatch&pageNumber=501"
browser.visit(url)

# %%
browser.is_element_not_present_by_css('span[class="article__timestamp"]')
# Out:
# True

# %%
df
# Out:
#                                              Headline  \
# 0   Apple has been hit with privacy complaints fro...
# 1   Momentum stocks may get an end-of-the-year pus...
# 2   Warren Buffett’s Berkshire Hathaway Confirms A...
# 3   Dow, S&P 500 end at record highs Monday as sto...
# 4   Apple Inc. stock rises Monday, outperforms market
# 5   Facebook Stock Could Continue to Rise. Here’s ...
# 6   Intel Has Fallen Behind Rivals and the Rest of...
# 7   U.S. Election Results and China Moves Bode Wel...
# 8     Here are Wall Street’s 20 favorite value stocks
# 9   Your ESG Portfolio Could Have Too Much Tech Ex...
# 10  Apple Inc. stock rises Friday, still underperf...
# 11  Moore’s Law Is Ending. Here’s What That Means ...
# 12  Apple's stock falls 0.6% to lead the 3 of 30 D...
# 13   It’s Time for Caution, a Top Market Expert Warns
# 14  What Stocks Did Warren Buffett’s Berkshire Buy...
# 15  How to Play the Value-Stock Boomlet—While It L...
# 16  The Dow Could Hit 30,000 Five Years Ahead of S...
# 17  iPhone X: Supply Is Tight; How to Still Get th...
# 18         Apple’s New MacBooks Leave Us Wanting More
# 19       Can’t Find that New iPhone? You’re Not Alone
# 20  Apple Inc. stock outperforms competitors despi...
# 21  Verizon Thinks You Should Be Excited About Its...
# 22  The Nasdaq Rose as the Dow Went Flat Because I...
# 23  Dow snaps 2-day win streak, Nasdaq gains as ro...
# 24  Apple Inc. stock rises Wednesday, outperforms ...
# 25  Apple’s New M1-Powered Mac Laptops Win Raves F...
# 26  Dow's 68-point climb highlighted by gains for ...
# 27  Dow climbs 88 points on gains for Salesforce.c...
# 28  Why the Stock Market Is Ignoring the Covid-19 ...
# 29  Apple's stock gains 1.4% premarket, after losi...
# ..                                                ...
# 70  Tech Stocks Are In Trouble No Matter Who Wins ...
# 71  You shouldn’t believe all this talk about a st...
# 72  Apple stock gains 0.6% premarket, after fallin...
# 73  Apple Inc. stock falls Monday, underperforms m...
# 74  Apple to hold Nov. 10 event, expected to bring...
# 75  A Giant Fund Sold Apple and Intel Stock. It Bo...
# 76  The Stock Market Could Could Crater If It Fall...
# 77  Nasdaq Composite Falls 2.4%, and Two More Numb...
# 78  ‘The Crown’ and ‘The Mandalorian’ return: Here...
# 79  Apple Music Could Be Worth $20 Billion by Itse...
# 80  Stock Market Suffered Its Worst Week Since Mar...
# 76   Oct. 30, 2020 at 4:40 p.m. ET
# 77    Nov. 2, 2020 at 4:00 a.m. ET
# 78   Oct. 27, 2020 at 5:16 p.m. ET
# 79  Jun. 11, 2019 at 11:04 a.m. ET
# 80  Oct. 30, 2020 at 10:09 p.m. ET
# 81   Oct. 31, 2020 at 1:23 p.m. ET
# 82   Oct. 12, 2020 at 2:53 p.m. ET
# 83  Oct. 27, 2020 at 10:10 a.m. ET
# 84   Oct. 26, 2020 at 1:10 p.m. ET
# 85   Oct. 29, 2020 at 9:11 p.m. ET
# 86   Oct. 30, 2020 at 5:14 p.m. ET
# 87   Oct. 30, 2020 at 4:55 p.m. ET
# 88   Oct. 30, 2020 at 5:48 a.m. ET
# 89   Oct. 30, 2020 at 4:07 p.m. ET
# 90   Oct. 30, 2020 at 3:49 p.m. ET
# 91   Oct. 30, 2020 at 3:44 p.m. ET
# 92   Oct. 30, 2020 at 3:19 p.m. ET
# 93   Oct. 30, 2020 at 1:49 p.m. ET
# 94   Oct. 30, 2020 at 1:27 p.m. ET
# 95  Oct. 30, 2020 at 12:27 p.m. ET
# 96   Jan. 28, 2019 at 6:00 a.m. ET
# 97    Jan. 9, 2019 at 1:56 p.m. ET
# 98   Sep. 25, 2018 at 2:30 p.m. ET
# 99  Feb. 14, 2018 at 10:20 a.m. ET
#
# [100 rows x 2 columns]

# %%
pd.to_datetime(df['Date']).dt.strftime('%Y-%m-%d')
# Out:
# C:\Users\godz7\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1206: UnknownTimezoneWarning: tzname ET identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# 0     2020-11-16
# 1     2020-11-17
# 2     2020-11-16
# 3     2020-11-16
# 4     2020-11-16
# 5     2020-11-16
# 6     2020-11-13
# 7     2020-11-14
# 8     2020-11-10
# 9     2020-11-14
# 10    2020-11-13
# 11    2020-11-13
# 12    2020-11-13
# 13    2020-11-13
# 14    2020-11-13
# 15    2020-11-12
# 16    2020-01-17
# 17    2017-10-27
# 18    2016-10-27
# 19    2016-10-19
# 20    2020-11-12
# 21    2020-11-11
# 22    2020-11-11
# 23    2020-11-11
# 24    2020-11-11
# 25    2020-11-11
# 26    2020-11-11
# 27    2020-11-11
# 28    2020-11-11
# 29    2020-11-11
#          ...
# 70    2020-11-02
# 71    2020-11-03
# 72    2020-11-03
# 73    2020-11-02
# 74    2020-11-02
# 75    2020-11-02
# 76    2020-10-30
# 77    2020-11-02
# 78    2020-10-27
# 79    2019-06-11
# 80    2020-10-30
# 81    2020-10-31
# 82    2020-10-12
# 83    2020-10-27
# 84    2020-10-26
# 85    2020-10-29
# 86    2020-10-30
# 87    2020-10-30
# 88    2020-10-30
# 89    2020-10-30
# 90    2020-10-30
# 91    2020-10-30
# 92    2020-10-30
# 93    2020-10-30
# 94    2020-10-30
# 95    2020-10-30
# 96    2019-01-28
# 97    2019-01-09
# 98    2018-09-25
# 99    2018-02-14
# Name: Date, Length: 100, dtype: object

# %%
AAPL_HEADLINES = df.drop_duplicates(subset=['Headline']).reset_index(drop=True)

# %%
AAPL_HEADLINES.to_csv('AAPL_HEADLINES.csv',header=True,index=False)
